# %% [markdown]
# <a href="https://colab.research.google.com/github/xuhu357/DataAnalysis/blob/master/ch02_%EC%82%AC%EB%A1%80_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 지난 사례에서 영화리뷰에 대해서 분석해보았고, 그럼 이번에는 이름에 대해서 분석해보자
#
# 분석할 내용: (미국 사회보장국에서 제공한 신생아 이름 정보)
#
#
# 1.   시대별로 특정 이름이 차지하는 비율로부터, 얼마나 흔한 이름인지 알아볼수 있다.
# 2.   이름의 상대 순위 알아보기
# 3.   각 연도별 가장 인기 있는 이름, 가장 빈도가 높거나 낮은 이름 알아보기
# 4.   모음, 자음, 길이, 전반적인 다양성, 철자 변화, 첫 글자와 마지막 글자 등, 이름 유행 분석하기
# 5.   성서에서 등장하는 이름, 유명인, 인구 통계학적 변화 등 외부 자료를 통한 유행 분석하기
#
# 지금까지 사용했던 라이브러를 이용해서, 위의 분석은 쉽게 할 수 있다.
#
#
# **그럼 Let's Go~!!!**

# %% [markdown]
# ### 일단 분석할 파일부터 준비하자.
#
# 데이터가 없다면, 사회 보장국 웹페이지에서 구할 수 있다.
# http://www.ssa.gov/oact/babynames/limits.html
#
#
# 다운로드 받았다고 치고, 일단 로컬에 있는 데이터를 업로드하고 열어보자.

# %%
# 로컬로부터 일단 파일을 업로드 해놓자
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-03de6710-6efe-4547-946c-7a073e368389" name="files[]" multiple disabled />
#      <output id="result-03de6710-6efe-4547-946c-7a073e368389">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving yob1880.txt to yob1880.txt
# User uploaded file "yob1880.txt" with length 24933 bytes

# %% [markdown]
# 당연하겠지만, yob1880.txt 파일은 올라가 있다.

# %%
# !ls
# Out:
# sample_data  yob1880.txt

# %%
file_name = 'yob1880.txt'

# %%
# !head -n 10 file_name
# Out:
# head: cannot open 'file_name' for reading: No such file or directory

# %% [markdown]
# 헐~, 뭐지? 분명이 ls 명령어로 확인했는데~음. 그럼 파일 이름을 변수에 담지 말고 그대로 입력하자

# %%
# !head -n 10 yob1880.txt
# Out:
# Mary,F,7065
# Anna,F,2604
# Emma,F,2003
# Elizabeth,F,1939
# Minnie,F,1746
# Margaret,F,1578
# Ida,F,1472
# Alice,F,1414
# Bertha,F,1320
# Sarah,F,1288

# %% [markdown]
# 유닉스의 head명령어에 '' 이 부호가 들어가서 안되는거였구나, 하긴 보통 command 창에서는 ' 부호를 넣지 않긴하지, 프로그래밍하고 헷갈렸쓰~
#
#
# ---
#
#
# 보셨겠지만 각 라인은 ','로 구분되어 있음, 그 말인즉 csv 형식으로 볼수 있다는 말~
#
# 그럼 pandas read_csv로 쉽게 불러올 수 있음.

# %%
# 일단 라이브러리부터 import 하자
import pandas as pd

# %%
names1880 = pd.read_csv(file_name, names=['name', 'sex', 'births'])

# %%
names1880.head()
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746

# %% [markdown]
# ???? 여자밖에 없는데, 남자는 어딧지? 전체 데이터를 한번  보자

# %%
names1880

# %% [markdown]
# 이 데이터는 각 연도별로 최소 5명 이상 중복되는 이름만 포함하고 있다.
#
# 편의상 성별 출생수를 모두 합한 값을 해당 연도의 전체 출생수라고 가정
#
# ---
#
# 즉 이 연도에 남자 ?명, 여자 ?명 태여났는지 확인 해보자

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %% [markdown]
# ### 본격적으로 분석을 시작하자.
#
# 현재까지는 1880년의 데이터만 보았는데, 실제로는 1880~2010년까지의 데이터를 모두 업로드하고, 전체에 대해서 분석하자

# %%
# 로컬로부터 일단 파일을 업로드 해놓자
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-133b4604-da64-4b4a-97d9-04d2e8176c82" name="files[]" multiple disabled />
#      <output id="result-133b4604-da64-4b4a-97d9-04d2e8176c82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving yob1881.txt to yob1881.txt
# Saving yob1882.txt to yob1882.txt
# Saving yob1883.txt to yob1883.txt
# Saving yob1884.txt to yob1884.txt
# Saving yob1885.txt to yob1885.txt
# Saving yob1886.txt to yob1886.txt
# Saving yob1887.txt to yob1887.txt
# Saving yob1888.txt to yob1888.txt
# Saving yob1889.txt to yob1889.txt
# Saving yob1890.txt to yob1890.txt
# Saving yob1891.txt to yob1891.txt
# Saving yob1892.txt to yob1892.txt
# Saving yob1893.txt to yob1893.txt
# Saving yob1894.txt to yob1894.txt
# Saving yob1895.txt to yob1895.txt
# Saving yob1896.txt to yob1896.txt
# Saving yob1897.txt to yob1897.txt
# Saving yob1898.txt to yob1898.txt
# Saving yob1899.txt to yob1899.txt
# Saving yob1900.txt to yob1900.txt
# Saving yob1901.txt to yob1901.txt
# Saving yob1902.txt to yob1902.txt
# Saving yob1903.txt to yob1903.txt
# Saving yob1904.txt to yob1904.txt
# Saving yob1905.txt to yob1905.txt
# Saving yob1906.txt to yob1906.txt
# Saving yob1907.txt to yob1907.txt
# Saving yob1908.txt to yob1908.txt
# Saving yob1909.txt to yob1909.txt
# Saving yob1910.txt to yob1910.txt
# Saving yob1911.txt to yob1911.txt
# Saving yob1912.txt to yob1912.txt
# Saving yob1913.txt to yob1913.txt
# Saving yob1914.txt to yob1914.txt
# Saving yob1915.txt to yob1915.txt
# Saving yob1916.txt to yob1916.txt
# Saving yob1917.txt to yob1917.txt
# Saving yob1918.txt to yob1918.txt
# Saving yob1919.txt to yob1919.txt
# Saving yob1920.txt to yob1920.txt
# Saving yob1921.txt to yob1921.txt
# Saving yob1922.txt to yob1922.txt
# Saving yob1923.txt to yob1923.txt
# Saving yob1924.txt to yob1924.txt
# Saving yob1925.txt to yob1925.txt
# Saving yob1926.txt to yob1926.txt
# Saving yob1927.txt to yob1927.txt
# Saving yob1928.txt to yob1928.txt
# Saving yob1929.txt to yob1929.txt
# Saving yob1930.txt to yob1930.txt
# Saving yob1931.txt to yob1931.txt
# Saving yob1932.txt to yob1932.txt
# Saving yob1933.txt to yob1933.txt
# Saving yob1934.txt to yob1934.txt
# Saving yob1935.txt to yob1935.txt
# User uploaded file "yob1996.txt" with length 342951 bytes
# User uploaded file "yob1997.txt" with length 349976 bytes
# User uploaded file "yob1998.txt" with length 361418 bytes
# User uploaded file "yob1999.txt" with length 369239 bytes
# User uploaded file "yob2000.txt" with length 384911 bytes
# User uploaded file "yob2001.txt" with length 390881 bytes
# User uploaded file "yob2002.txt" with length 394589 bytes
# User uploaded file "yob2003.txt" with length 402312 bytes
# User uploaded file "yob2004.txt" with length 413102 bytes
# User uploaded file "yob2005.txt" with length 419688 bytes
# User uploaded file "yob2006.txt" with length 439715 bytes
# User uploaded file "yob2007.txt" with length 450391 bytes
# User uploaded file "yob2008.txt" with length 451900 bytes
# User uploaded file "yob2009.txt" with length 446675 bytes
# User uploaded file "yob2010.txt" with length 436566 bytes

# %% [markdown]
# 현재는 자료가 연도별로 나누어져 있는데, 이들을 DataFrame 하나로 취합한후 year항목을 추가하자.
#
#
# 합치는것은 pandas.concat를 이용하면 이 작업을 쉽게 할 수 있다.

# %%
years = range(1880, 2011)

pieces = []
columns = ['name', 'sex', 'births']

for year in years:
  path = 'yob%d.txt' % year
  frame = pd.read_csv(path, names=columns)
  
  frame['year'] = year
  pieces.append(frame)
  
names = pd.concat(pieces, ignore_index=True)

# %% [markdown]
# ### 여기서 잠깐~
#
# concat()는 DataFrame 객체를 이어붙여주는 역할을 함.
#
#
# ignore_index는 우리가 read_csv를 통해서 읽어온 원래 행의 순서를 몰라도 됨으로 index를 ignore하겠다는 뜻임~

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     794  1880
# 23          Jennie   F     793  1880
# 24        Gertrude   F     787  1880
# 25           Julia   F     783  1880
# 26          Hattie   F     769  1880
# 27           Edith   F     768  1880
# 28          Mattie   F     704  1880
# 29            Rose   F     700  1880
# ...            ...  ..     ...   ...
# 1690754    Zaviyon   M       5  2010
# 1690755   Zaybrien   M       5  2010
# 1690756   Zayshawn   M       5  2010
# 1690757     Zayyan   M       5  2010
# 1690758       Zeal   M       5  2010
# 1690759     Zealan   M       5  2010
# 1690760   Zecharia   M       5  2010
# 1690761   Zeferino   M       5  2010
# 1690762   Zekariah   M       5  2010
# 1690763       Zeki   M       5  2010
# 1690764     Zeriah   M       5  2010
# 1690765     Zeshan   M       5  2010
# 1690766     Zhyier   M       5  2010
# 1690767   Zildjian   M       5  2010
# 1690768       Zinn   M       5  2010
# 1690769     Zishan   M       5  2010
# 1690770      Ziven   M       5  2010
# 1690771      Zmari   M       5  2010
# 1690772      Zoren   M       5  2010
# 1690773     Zuhaib   M       5  2010
# 1690774     Zyeire   M       5  2010
# 1690775    Zygmunt   M       5  2010
# 1690776   Zykerion   M       5  2010
# 1690777      Zylar   M       5  2010
# 1690778      Zylin   M       5  2010
# 1690779    Zymaire   M       5  2010
# 1690780     Zyonne   M       5  2010
# 1690781  Zyquarius   M       5  2010
# 1690782      Zyran   M       5  2010
# 1690783      Zzyzx   M       5  2010
#
# [1690784 rows x 4 columns]

# %% [markdown]
# 이제는 groupby() 나 pivot_table() 메소드를 사용해서 연도나 성별에 따른 데이터를 수집할 수 있음~
#
# groupby() 전에 한번 구경해보았고, 이번에는 그럼 pivot_table()을 사용해보자~

# %%
total_births = names.pivot_table('births', index='year', columns='sex', aggfunc=sum)

# %%
total_births.tail()
# Out:
# sex         F        M
# year
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382

# %% [markdown]
# 음~~
#
# 각 년도별, Female, Male 출생수구하는 것임.
#
# tail()은 head() 와 비슷하지만, 마지막 몇개를 보여주는 함수구나~
#
# ---
#
# 그림으로 한번 볼까?

# %%
total_births.plot(title='Total births by sex and year')

# %% [markdown]
# 이번에 해볼 일은, dataframe에 prop라는 열을 추가해서,  각 이름이 전체 출생수에서 차지하는 비율이 얼마인지를 계산하는것임.

# %%
def add_prop(group):
  births = group.births.astype(float)
  group['prop'] = births / births.sum()
  return group

# %%
names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.077643
# 1             Anna   F    2604  1880  0.028618
# 2             Emma   F    2003  1880  0.022013
# 3        Elizabeth   F    1939  1880  0.021309
# 4           Minnie   F    1746  1880  0.019188
# 5         Margaret   F    1578  1880  0.017342
# 6              Ida   F    1472  1880  0.016177
# 7            Alice   F    1414  1880  0.015540
# 8           Bertha   F    1320  1880  0.014507
# 9            Sarah   F    1288  1880  0.014155
# 10           Annie   F    1258  1880  0.013825
# 11           Clara   F    1226  1880  0.013474
# 12            Ella   F    1156  1880  0.012704
# 13        Florence   F    1063  1880  0.011682
# 14            Cora   F    1045  1880  0.011484
# 15          Martha   F    1040  1880  0.011429
# 16           Laura   F    1012  1880  0.011122
# 17          Nellie   F     995  1880  0.010935
# 18           Grace   F     982  1880  0.010792
# 19          Carrie   F     949  1880  0.010429
# 20           Maude   F     858  1880  0.009429
# 21           Mabel   F     808  1880  0.008880
# 22          Bessie   F     794  1880  0.008726
# 23          Jennie   F     793  1880  0.008715
# 24        Gertrude   F     787  1880  0.008649
# 25           Julia   F     783  1880  0.008605
# 26          Hattie   F     769  1880  0.008451
# 27           Edith   F     768  1880  0.008440
# 28          Mattie   F     704  1880  0.007737
# 29            Rose   F     700  1880  0.007693
# ...            ...  ..     ...   ...       ...
# 1690754    Zaviyon   M       5  2010  0.000003
# 1690755   Zaybrien   M       5  2010  0.000003
# 1690756   Zayshawn   M       5  2010  0.000003
# 1690757     Zayyan   M       5  2010  0.000003
# 1690758       Zeal   M       5  2010  0.000003
# 1690759     Zealan   M       5  2010  0.000003
# 1690760   Zecharia   M       5  2010  0.000003
# 1690761   Zeferino   M       5  2010  0.000003
# 1690762   Zekariah   M       5  2010  0.000003
# 1690763       Zeki   M       5  2010  0.000003
# 1690764     Zeriah   M       5  2010  0.000003
# 1690765     Zeshan   M       5  2010  0.000003
# 1690766     Zhyier   M       5  2010  0.000003
# 1690767   Zildjian   M       5  2010  0.000003
# 1690768       Zinn   M       5  2010  0.000003
# 1690769     Zishan   M       5  2010  0.000003
# 1690770      Ziven   M       5  2010  0.000003
# 1690771      Zmari   M       5  2010  0.000003
# 1690772      Zoren   M       5  2010  0.000003
# 1690773     Zuhaib   M       5  2010  0.000003
# 1690774     Zyeire   M       5  2010  0.000003
# 1690775    Zygmunt   M       5  2010  0.000003
# 1690776   Zykerion   M       5  2010  0.000003
# 1690777      Zylar   M       5  2010  0.000003
# 1690778      Zylin   M       5  2010  0.000003
# 1690779    Zymaire   M       5  2010  0.000003
# 1690780     Zyonne   M       5  2010  0.000003
# 1690781  Zyquarius   M       5  2010  0.000003
# 1690782      Zyran   M       5  2010  0.000003
# 1690783      Zzyzx   M       5  2010  0.000003
#
# [1690784 rows x 5 columns]

# %% [markdown]
# Wow~!!! Bravo~!!!
#
# 그런데, 모든 prop의 합이 1이 맞음? 맞겠지~~근데 어떻게 확인하지?
# 다행히, 이런 sanity check를 해줄수 있는 함수가 있다.
#
# 바로 np.allclose() 하는 함수~let's do it~

# %%
import numpy as np

# %%
np.allclose(names.groupby(['year', 'sex']).prop.sum(), 1)
# Out:
# True

# %% [markdown]
# 오케이 이렇게 하면, **모든 준비는 거의 끝났다고 볼수 있음**.
#
# 이젠 본격적인 분석 작업에 들어가자~
#
# 데이터가 너무 크니, 일단 각 연도별, 성별에 따른 빈도수가 가장 높은 이름 1000개를 추출하자.

# %%
def get_top1000(group):
  return group.sort_values(by='births', ascending=False)[:1000]

# %%
grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
top1000.index = np.arange(len(top1000))

# %%
len(top1000)
# Out:
# 261877

# %%
top1000
# Out:
#              name sex  births  year      prop
# 0            Mary   F    7065  1880  0.077643
# 1            Anna   F    2604  1880  0.028618
# 2            Emma   F    2003  1880  0.022013
# 3       Elizabeth   F    1939  1880  0.021309
# 4          Minnie   F    1746  1880  0.019188
# 5        Margaret   F    1578  1880  0.017342
# 6             Ida   F    1472  1880  0.016177
# 7           Alice   F    1414  1880  0.015540
# 8          Bertha   F    1320  1880  0.014507
# 9           Sarah   F    1288  1880  0.014155
# 10          Annie   F    1258  1880  0.013825
# 11          Clara   F    1226  1880  0.013474
# 12           Ella   F    1156  1880  0.012704
# 13       Florence   F    1063  1880  0.011682
# 14           Cora   F    1045  1880  0.011484
# 15         Martha   F    1040  1880  0.011429
# 16          Laura   F    1012  1880  0.011122
# 17         Nellie   F     995  1880  0.010935
# 18          Grace   F     982  1880  0.010792
# 19         Carrie   F     949  1880  0.010429
# 20          Maude   F     858  1880  0.009429
# 21          Mabel   F     808  1880  0.008880
# 22         Bessie   F     794  1880  0.008726
# 23         Jennie   F     793  1880  0.008715
# 24       Gertrude   F     787  1880  0.008649
# 25          Julia   F     783  1880  0.008605
# 26         Hattie   F     769  1880  0.008451
# 27          Edith   F     768  1880  0.008440
# 28         Mattie   F     704  1880  0.007737
# 29           Rose   F     700  1880  0.007693
# ...           ...  ..     ...   ...       ...
# 261847       Yair   M     201  2010  0.000106
# 261848      Talan   M     201  2010  0.000106
# 261849      Keyon   M     201  2010  0.000106
# 261850       Kael   M     201  2010  0.000106
# 261851   Demarion   M     200  2010  0.000105
# 261852     Gibson   M     200  2010  0.000105
# 261853     Reagan   M     200  2010  0.000105
# 261854  Cristofer   M     199  2010  0.000105
# 261855     Daylen   M     199  2010  0.000105
# 261856     Jordon   M     199  2010  0.000105
# 261857    Dashawn   M     198  2010  0.000104
# 261858      Masen   M     198  2010  0.000104
# 261859      Rowen   M     197  2010  0.000104
# 261860     Yousef   M     197  2010  0.000104
# 261861   Thaddeus   M     197  2010  0.000104
# 261862      Kadin   M     197  2010  0.000104
# 261863     Dillan   M     197  2010  0.000104
# 261864   Clarence   M     197  2010  0.000104
# 261865      Slade   M     196  2010  0.000103
# 261866    Clinton   M     196  2010  0.000103
# 261867    Sheldon   M     196  2010  0.000103
# 261868    Keshawn   M     195  2010  0.000103
# 261869   Menachem   M     195  2010  0.000103
# 261870     Joziah   M     195  2010  0.000103
# 261871     Bailey   M     194  2010  0.000102
# 261872     Camilo   M     194  2010  0.000102
# 261873     Destin   M     194  2010  0.000102
# 261874     Jaquan   M     194  2010  0.000102
# 261875     Jaydan   M     194  2010  0.000102
# 261876     Maxton   M     193  2010  0.000102
#
# [261877 rows x 5 columns]

# %% [markdown]
# ### How?
# 어떻게 이런 결과지? 1000개씩 뽑는다며???
#
# 연도수: (2010-1880+1) = 131
# 성별: F, M 두개씩
# 각각: 1000개
# 1000 * 2 * 131 = 262,000
#
# 이중에서, 어떤 것은 1000개 미만일수도 있으니, 약 261877이란 결과가 나왔을 것 같음~

# %% [markdown]
# ### 1) 이름 유행 분석

# %%
boys = top1000[top1000.sex == 'M']
girls = top1000[top1000.sex == 'F']

# %% [markdown]
# 연도별로 John이나, Mary라는 이름의 추이를 간단하게 그래프로 만들어보자
#
# 그러기 위해서는, 연도와 이름에 대한 전체 출생수를 pivot table로 만들어보자.

# %%
total_births = top1000.pivot_table('births', index='year', columns='name', aggfunc=sum)

# %%
total_births
# Out:
# 1999  430.0  ...     NaN  3238.0   561.0  257.0   NaN     NaN   NaN   NaN
# 2000  432.0  ...     NaN  3783.0   691.0  320.0   NaN     NaN   NaN   NaN
# 2001  526.0  ...     NaN  4642.0   822.0  439.0   NaN     NaN   NaN   NaN
# 2002  514.0  ...     NaN  4883.0  1182.0  438.0   NaN     NaN   NaN   NaN
# 2003  536.0  ...     NaN  5080.0  1465.0  448.0   NaN     NaN   NaN   NaN
# 2004  500.0  ...     NaN  5359.0  1621.0  515.0   NaN     NaN   NaN   NaN
# 2005  445.0  ...     NaN  4953.0  2266.0  502.0   NaN     NaN   NaN   NaN
# 2006  440.0  ...     NaN  5145.0  2839.0  530.0   NaN     NaN   NaN   NaN
# 2007  468.0  ...     NaN  4925.0  3028.0  526.0   NaN     NaN   NaN   NaN
# 2008  400.0  ...     NaN  4764.0  3438.0  492.0   NaN     NaN   NaN   NaN
# 2009  369.0  ...     NaN  5120.0  3981.0  496.0   NaN     NaN   NaN   NaN
# 2010  324.0  ...     NaN  6200.0  5164.0  504.0   NaN     NaN   NaN   NaN
#
# name  Zula   Zuri
# year
# 1880  27.0    NaN
# 1881  27.0    NaN
# 1882  21.0    NaN
# 1883  25.0    NaN
# 1884  27.0    NaN
# 1885  38.0    NaN
# 1886  43.0    NaN
# 1887  33.0    NaN
# 1888  45.0    NaN
# 1889  55.0    NaN
# 1890  65.0    NaN
# 1891  45.0    NaN
# 1892  53.0    NaN
# 1893  70.0    NaN
# 1894  64.0    NaN
# 1895  55.0    NaN
# 1896  65.0    NaN
# 1897  79.0    NaN
# 1898  83.0    NaN
# 1899  60.0    NaN
# 1900  71.0    NaN
# 1901  57.0    NaN
# 1902  66.0    NaN
# 1903  74.0    NaN
# 1904  74.0    NaN
# 1905  61.0    NaN
# 1906  58.0    NaN
# 1907  72.0    NaN
# 1908  53.0    NaN
# 1909  76.0    NaN
# ...    ...    ...
# 1981   NaN    NaN
# 1982   NaN    NaN
# 1983   NaN    NaN
# 1984   NaN    NaN
# 1985   NaN    NaN
# 1986   NaN    NaN
# 1987   NaN    NaN
# 1988   NaN    NaN
# 1989   NaN    NaN
# 1990   NaN    NaN
# 1991   NaN    NaN
# 1992   NaN    NaN
# 1993   NaN    NaN
# 1994   NaN    NaN
# 1995   NaN    NaN
# 1996   NaN    NaN
# 1997   NaN    NaN
# 1998   NaN    NaN
# 1999   NaN    NaN
# 2000   NaN    NaN
# 2001   NaN    NaN
# 2002   NaN    NaN
# 2003   NaN    NaN
# 2004   NaN    NaN
# 2005   NaN    NaN
# 2006   NaN    NaN
# 2007   NaN    NaN
# 2008   NaN    NaN
# 2009   NaN    NaN
# 2010   NaN  258.0
#
# [131 rows x 6868 columns]

# %%
total_births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 1880 to 2010
# Columns: 6868 entries, Aaden to Zuri
# dtypes: float64(6868)
# memory usage: 6.9 MB

# %% [markdown]
# 'John', 'Harry', 'Mary', 'Marilyn' 등 일부 이름의 추세만 보고 싶다면,

# %%
subset = total_births[['John', 'Harry', 'Mary', 'Marilyn']]

# %%
subset.plot(subplots=True, figsize=(12, 10), grid=False, title='Number of births per year')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3bf183e630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f3bf0fb8be0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f3bf0f780b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f3bf0fa5a20>],
#       dtype=object)

# %% [markdown]
# **깜짝 질문: **
#
# 위의 그래프로 부터 어떤 결론을 얻을수 있을까?
#
# (힌트: avoid, )

# %% [markdown]
# #### 다양한 이름을 사용하는 경향 파악하기

# %%
table = top1000.pivot_table('prop', index='year', columns='sex', aggfunc=sum)

# %% [markdown]
# 위의 조작은 뭘 확인하는걸까요?

# %%
table
# Out:
# sex          F         M
# year
# 1880  1.000000  0.997375
# 1881  1.000000  1.000000
# 1882  0.998702  0.995646
# 1883  0.997596  0.998566
# 1884  0.993156  0.994539
# 1885  0.992251  0.995501
# 1886  0.989504  0.995035
# 1887  0.988279  0.996697
# 1888  0.984241  0.992429
# 1889  0.984061  0.994981
# 1890  0.982566  0.992749
# 1891  0.982177  0.993725
# 1892  0.979746  0.988815
# 1893  0.980001  0.991720
# 1894  0.978571  0.989048
# 1895  0.975479  0.989071
# 1896  0.975660  0.988041
# 1897  0.976558  0.989349
# 1898  0.972806  0.987197
# 1899  0.975170  0.990115
# 1900  0.967760  0.979702
# 1901  0.972304  0.989603
# 1902  0.970467  0.985749
# 1903  0.969490  0.986020
# 1904  0.968142  0.982502
# 1905  0.967038  0.981650
# 1906  0.967535  0.981759
# 1907  0.964942  0.976975
# 1908  0.964500  0.976409
# 1909  0.962744  0.973412
# ...        ...       ...
# 1981  0.867232  0.944762
# 1982  0.868208  0.944435
# 1983  0.871602  0.945170
# 1984  0.870201  0.944705
# 1985  0.866046  0.942412
# 1986  0.862619  0.939833
# 1987  0.858719  0.937574
# 1988  0.852520  0.934236
# 1989  0.846535  0.928314
# 1990  0.840591  0.926585
# 1991  0.835156  0.923316
# 1992  0.829654  0.919513
# 1993  0.826035  0.915127
# 1994  0.823227  0.911285
# 1995  0.821738  0.909356
# 1996  0.817149  0.905296
# 1997  0.811416  0.901020
# 1998  0.805665  0.896381
# 1999  0.799804  0.892714
# 2000  0.791455  0.887008
# 2001  0.784125  0.882799
# 2002  0.780403  0.879775
# 2003  0.774850  0.876747
# 2004  0.767291  0.870077
# 2005  0.762426  0.866514
# 2006  0.753153  0.860368
# 2007  0.745959  0.855159
# 2008  0.740933  0.850003
# 2009  0.737290  0.845256
# 2010  0.736780  0.843156
#
# [131 rows x 2 columns]

# %% [markdown]
# 답은, 인기있는 top 1000개의 이름이 전체 출생수에서 차지하는 비율이 얼마 되는가를 확인 하는 것임.

# %%
table.plot(title='Sum of table1000.prop by year and sex', yticks=np.linspace(0, 1.2, 13), xticks=range(1880, 2020, 10))

# %% [markdown]
# **Can you get something? **
#
# top1000 이름들이 전체 출생수에서 차지하는 비율이 줄어드는것을 알수 있음.
# 그 말인즉 부모들이 흔한 이름은 피해서 이름을 짓는다는 것을 의미함.
#
# **다른 말로 하면, **
#
# 이름의 다양성이 높아진다는 말임.

# %%
df = boys[boys.year == 2010]

# %%
df

# %% [markdown]
# 또 인기 있는 이름순으로 정렬했을 때, 전체 출생수의 50%를 차지하기까지 등장하는 이름의 개수도 한번 보자~

# %%
prop_cumsum = df.sort_values(by='prop', ascending=False).prop.cumsum()

# %%
prop_cumsum[:10]
# Out:
# 260877    0.011523
# 260878    0.020934
# 260879    0.029959
# 260880    0.038930
# 260881    0.047817
# 260882    0.056579
# 260883    0.065155
# 260884    0.073414
# 260885    0.081528
# 260886    0.089621
# Name: prop, dtype: float64

# %%
prop_cumsum.values.searchsorted(0.5)
# Out:
# 116

# %%
df = boys[boys.year == 1900]

# %%
in1900 = df.sort_values(by='prop', ascending=False).prop.cumsum()

# %%
in1900.values.searchsorted(0.5)+1
# Out:
# 25

# %% [markdown]
# 해석해보자면,
#
# 1900년에는 상위 25개의 이름이 전체 출생아 이름의 50%를 차지했던 방면에
# 2010년에는 상위 117개의 이름이 전체 출생아 이름의 50%를 차지했다.
#
# 그 말인즉,
# 2010년에는 1900년보다 남자이름이 더 다양해졌다는 뜻이다~!!

# %% [markdown]
# #### 그럼 이 연산을 각 연도와 성별 조합에 적용해보자~

# %%
def get_quantile_count(group, q=0.5):
  group = group.sort_values(by='prop', ascending=False)
  return group.prop.cumsum().values.searchsorted(q) + 1

# %%
diversity = top1000.groupby(['year', 'sex']).apply(get_quantile_count)

# %%
diversity
# Out:
# year  sex
# 1880  F       38
#       M       14
# 1881  F       38
#       M       14
# 1882  F       38
#       M       15
# 1883  F       39
#       M       15
# 1884  F       39
#       M       16
# 1885  F       40
#       M       16
# 1886  F       41
#       M       16
# 1887  F       41
#       M       17
# 1888  F       42
#       M       17
# 1889  F       43
#       M       18
# 1890  F       44
#       M       19
# 1891  F       44
#       M       20
# 1892  F       44
#       M       20
# 1893  F       44
#       M       21
# 1894  F       45
#       M       22
#             ...
# 1996  F      122
#       M       64
# 1997  F      129
#       M       67
# 1998  F      138
#       M       70
# 1999  F      146
#       M       73
# 2000  F      155
#       M       77
# 2001  F      164
#       M       81
# 2002  F      170
#       M       83
# 2003  F      178
#       M       87
# 2004  F      191
#       M       92
# 2005  F      199
#       M       96
# 2006  F      209
#       M       99
# 2007  F      223
#       M      103
# 2008  F      234
#       M      109
# 2009  F      241
#       M      114
# 2010  F      246
#       M      117
# Length: 262, dtype: int64

# %% [markdown]
# 거 참, Not Bad 인데, 좀 만 더 이쁘게 표현해보자~

# %%
diversity = diversity.unstack('sex')

# %%
diversity.head()
# Out:
# sex    F   M
# year
# 1880  38  14
# 1881  38  14
# 1882  38  15
# 1883  39  15
# 1884  39  16

# %%
diversity.plot(title='Number of popular names in top 50%', xticks=range(1880, 2020, 10))

# %% [markdown]
# **What do you Get from this Chart?**
#
#
#
# 1.   여자 이름은 항상 남자 이름보다 다양하다
# 2.   시간이 흐를수록 더욱 다양해지고 있다. 남녀불문
